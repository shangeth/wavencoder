# %% [markdown]
# # Additive noise

# %%
from wavencoder.transforms.noise import AdditiveNoise
import torchaudio

add = AdditiveNoise('/home/shangeth/Downloads/Dataset/DLIVING_16k/DLIVING')
audio, _ = torchaudio.load('/home/shangeth/Downloads/Dataset/TIMIT/Wav_Data/TRAIN/FAEM0_SA2.WAV')

noisy = add(audio)

# %%
audio.shape, noisy.shape
# Out:
# (torch.Size([1, 45261]), torch.Size([1, 45261]))

# %%
import IPython
import matplotlib.pyplot as plt


plt.plot(audio.reshape(-1))
plt.show()

IPython.display.Audio(audio.reshape(-1), rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(noisy.reshape(-1))
plt.show()

IPython.display.Audio(noisy.reshape(-1), rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Speed

# %%
from wavencoder.transforms.speed import SpeedChange
import torchaudio

speed = SpeedChange(factor_range=(-1, 2))
audio, _ = torchaudio.load('/home/shangeth/Downloads/Dataset/TIMIT/Wav_Data/TRAIN/FAEM0_SA2.WAV')

speedy = speed(audio)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1b7d95d40b90> in <module>
#       5 audio, _ = torchaudio.load('/home/shangeth/Downloads/Dataset/TIMIT/Wav_Data/TRAIN/FAEM0_SA2.WAV')
#       6
# ----> 7 speedy = speed(audio)
#
# ~/Documents/GitHub/WavEncoder/wavencoder/transforms/speed.py in __call__(self, wav)
#      13         warp_factor = random.random() * (self.factor_range[1] - self.factor_range[0]) + self.factor_range[0]
#      14         samp_warp = wav.shape[0] + int(warp_factor * wav.shape[0])
# ---> 15         rwav = kaldi.resample_waveform(wav.view(1, -1), self.orig_freq, samp_warp)
#      16         rwav = rwav.view(-1)
#      17
#
# ~/anaconda3/envs/dcase/lib/python3.8/site-packages/torchaudio/compliance/kaldi.py in resample_waveform(waveform, orig_freq, new_freq, lowpass_filter_width)
#     967
#     968         # we want conv_wave[:, i] to be at output[:, i + n*conv_transpose_stride]
# --> 969         dilated_conv_wave = torch.nn.functional.conv_transpose1d(
#     970             conv_wave, eye, stride=conv_transpose_stride).squeeze(0)
#     971
#
# KeyboardInterrupt:

# %%
import IPython
import matplotlib.pyplot as plt

plt.plot(audio.reshape(-1))
plt.show()

IPython.display.Audio(audio.reshape(-1), rate=16000)

# %%
plt.plot(speedy.reshape(-1))
plt.show()

IPython.display.Audio(speedy.reshape(-1), rate=16000)
